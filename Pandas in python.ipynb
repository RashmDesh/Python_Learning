# %% [markdown]
# # Pandas in python

# %% [markdown]
# # What is Pandas?
#
# Pandas is a Python library used for working with data sets.
#
# It has functions for analyzing, cleaning, exploring, and manipulating data.
#
# The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis" and was created by Wes McKinney in 2008.

# %% [markdown]
# # Why Use Pandas?
#
# Pandas allows us to analyze big data and make conclusions based on statistical theories.
# Pandas can clean messy data sets, and make them readable and relevant.
# Relevant data is very important in data science.
#
# Data Science: is a branch of computer science where we study how to store,
# use and analyze data for deriving information from it.

# %% [markdown]
# # Import Pandas
#
# Once Pandas is installed, import it in your applications by adding the import keyword:

# %%
import pandas

# %% [markdown]
# # Pandas as pd
#
# Pandas is usually imported under the pd alias.
#
# alias: In Python alias are an alternate name for referring to the same thing.

# %%
import pandas as pd

# %% [markdown]
# Checking Pandas Version
# The version string is stored under __version__ attribute.

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 0.23.4

# %% [markdown]
# # Core components of pandas: Series and DataFrames
#
# The primary two components of pandas are the Series and DataFrame.

# %% [markdown]
# # Pandas Series

# %% [markdown]
# # What is a Series?
#
# A Pandas Series is like a column in a table.
# It is a one-dimensional array holding data of any type.

# %%
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a)

print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %% [markdown]
# # Labels
# If nothing else is specified, the values are labeled with their index number. First value has index 0, second value has index 1 etc.
#
# This label can be used to access a specified value.

# %%
print(myvar[0])
print(myvar[1])
# Out:
# 1
# 7

# %% [markdown]
# # Create Labels
#
# With the index argument, you can name your own labels.

# %%
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a, index = ["x", "y", "z"])

print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %% [markdown]
# When you have created labels, you can access an item by referring to the label

# %%
print(myvar["x"])
print(myvar["y"])
print(myvar["z"])
# Out:
# 1
# 7
# 2

# %% [markdown]
# # Key/Value Objects as Series
#
# You can also use a key/value object, like a dictionary, when creating a Series.

# %%
import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %% [markdown]
# To select only some of the items in the dictionary,
# use the index argument and specify only the items you want to include in the Series.

# %%
import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories, index = ["day1", "day2"])

print(myvar)
# Out:
# day1    420
# day2    380
# dtype: int64

# %% [markdown]
# # Pandas DataFrames

# %% [markdown]
# Data sets in Pandas are usually multi-dimensional tables, called DataFrames.
# Series is like a column, a DataFrame is the whole table.

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %% [markdown]
# # Locate Row
# As you can see from the result above, the DataFrame is like a table with rows and columns.
#
# Pandas use the loc attribute to return one or more specified row(s)

# %%
#refer to the row index:
print(df.loc[0])
print(df.loc[1])
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64
# calories    380
# duration     40
# Name: 1, dtype: int64

# %%
#use a list of indexes:
print(df.loc[[0, 1]])
# Out:
#    calories  duration
# 0       420        50
# 1       380        40

# %% [raw]
# # Note: When using [], the result is a Pandas DataFrame.

# %% [markdown]
# # Named Indexes
# With the index argument, you can name your own indexes.

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %% [markdown]
# # Locate Named Indexes
#
# Use the named index in the loc attribute to return the specified row(s).

# %%
#refer to the named index:
print(df.loc["day1"])
print(df.loc["day2"])
# Out:
# calories    420
# duration     50
# Name: day1, dtype: int64
# calories    380
# duration     40
# Name: day2, dtype: int64

# %% [markdown]
# # Load Files Into a DataFrame

# %% [markdown]
# If your data sets are stored in a file, Pandas can load them into a DataFrame.

# %%
import pandas as pd

df = pd.read_csv('C:/Users/lenovo/Desktop/datasets/movies.csv')

print(df)
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# 5            6                                        Heat (1995)
# 6            7                                     Sabrina (1995)
# 7            8                                Tom and Huck (1995)
# 8            9                                Sudden Death (1995)
# 9           10                                   GoldenEye (1995)
# 10          11                     American President, The (1995)
# 11          12                 Dracula: Dead and Loving It (1995)
# 12          13                                       Balto (1995)
# ...

# %% [markdown]
# # Pandas Read CSV

# %% [markdown]
# # Read CSV Files
#
# A simple way to store big data sets is to use CSV files (comma separated files).
# CSV files contains plain text and is a well know format that can be read by everyone including Pandas.

# %%
import pandas as pd

df = pd.read_csv('C:/Users/lenovo/Desktop/datasets/data.csv')

print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
import pandas as pd

df = pd.read_csv('C:/Users/lenovo/Desktop/datasets/data.csv')

print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %% [markdown]
# # Pandas Read JSON

# %% [markdown]
# # Read JSON
#
# Big data sets are often stored, or extracted as JSON.
# JSON is plain text, but has the format of an object, and is well known in the world of programming, including Pandas.

# %%
import pandas as pd

df = pd.read_json('C:/Users/lenovo/Desktop/datasets/data.js')

print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 10         60    103       147     329.3
# 100        20     95       112      77.7
# 101        90     90       110     500.0
# 102        90     90       100     500.0
# 103        90     90       100     500.4
# 104        30     92       108      92.7
# 105        30     93       128     124.0
# 106       180     90       120     800.3
# 107        30     90       120      86.2
# 108        90     90       120     500.3
# 109       210    137       184    1860.4
# 11         60    100       120     250.7
# 110        60    102       124     325.2
# 111        45    107       124     275.0
# 112        15    124       139     124.2
# 113        45    100       120     225.3
# 114        60    108       131     367.6
# 115        60    108       151     351.7
# 116        60    116       141     443.0
# 117        60     97       122     277.4
# ...

# %% [markdown]
# # Dictionary as JSON
#
# JSON = Python Dictionary
#
# JSON objects have the same format as Python dictionaries.
#
# If your JSON code is not in a file, but in a Python Dictionary, you can load it into a DataFrame directly:

# %%
data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %% [markdown]
# # head  and tail method
# The head() method returns the headers and a specified number of rows, starting from the top.
# The tail() method returns the headers and a specified number of rows, starting from the bottom.

# %%
import pandas as pd

df = pd.read_json('C:/Users/lenovo/Desktop/datasets/data.js')

print(df.head(10))
print(df.tail())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 10         60    103       147     329.3
# 100        20     95       112      77.7
# 101        90     90       110     500.0
# 102        90     90       100     500.0
# 103        90     90       100     500.4
# 104        30     92       108      92.7
# 105        30     93       128     124.0
# 106       180     90       120     800.3
#     Duration  Pulse  Maxpulse  Calories
# 95        20    151       168     229.4
# 96        30     95       128     128.2
# 97        25    152       168     244.2
# 98        30    109       131     188.2
# 99        90     93       124     604.1

# %% [raw]
# Note: if the number of rows is not specified, the head() and tail method will return the top 5 rows.

# %%
# info about data
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 169 entries, 0 to 99
# Data columns (total 4 columns):
# Duration    169 non-null int64
# Pulse       169 non-null int64
# Maxpulse    169 non-null int64
# Calories    164 non-null float64
# dtypes: float64(1), int64(3)
# memory usage: 6.6 KB
# None

# %% [markdown]
# # Pandas - Cleaning Data

# %% [markdown]
# # Data Cleaning
#
# Data cleaning means fixing bad data in your data set.
#
# Bad data could be:
# Empty cells
# Data in wrong format
# Wrong data
# Duplicates

# %% [markdown]
# # Empty Cells
# Empty cells can potentially give you a wrong result when you analyze data.
#
# Remove Rows
# One way to deal with empty cells is to remove rows that contain empty cells.
#
# This is usually OK, since data sets can be very big, and removing a few rows will not have a big impact on the result.

# %%
import pandas as pd

df = pd.read_csv('C:/Users/lenovo/Desktop/datasets/Sampledata.csv')

new_df = df.dropna()

print(new_df.head())
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %% [markdown]
# Note: By default, the dropna() method returns a new DataFrame, and will not change the original.
#     If you want to change the original DataFrame, use the inplace = True argument:

# %%
import pandas as pd

df = pd.read_csv('C:/Users/lenovo/Desktop/datasets/Sampledata.csv')

new_df = df.dropna(inplace = True)

print(new_df.head())

# %% [markdown]
# Note: Now, the dropna(inplace = True) will NOT return a new DataFrame,
# but it will remove all rows containg NULL values from the original DataFrame.

# %% [markdown]
# # Replace Empty Values
#
# Another way of dealing with empty cells is to insert a new value instead.
# This way you do not have to delete entire rows just because of some empty cells.
# The fillna() method allows us to replace empty cells with a value:

# %%
Replace NULL values with the number 130:
import pandas as pd

df = pd.read_csv('C:/Users/lenovo/Desktop/datasets/Sampledata.csv')

df.fillna(130, inplace = True)

# %%
Replace NULL values in the "Calories" columns with the number 130:

# %%
import pandas as pd

df = pd.read_csv('C:/Users/lenovo/Desktop/datasets/Sampledata.csv')

df["Calories"].fillna(130, inplace = True)
print(df["Calories"])
# Out:
# 0     409.1
# 1     479.0
# 2     340.0
# 3     282.4
# 4     406.0
# 5     300.0
# 6     374.0
# 7     253.3
# 8     195.1
# 9     269.0
# 10    329.3
# 11    250.7
# 12    250.7
# 13    345.3
# 14    379.3
# 15    275.0
# 16    215.2
# 17    300.0
# 18    130.0
# 19    323.0
# 20    243.0
# 21    364.2
# 22    282.0
# 23    300.0
# 24    246.0
# 25    334.5
# 26    250.0
# 27    241.0
# 28    130.0
# 29    280.0
# 30    380.3
# 31    243.0
# Name: Calories, dtype: float64

# %% [markdown]
# # Mean, Median, or Mode

# %% [markdown]
# Pandas uses the mean() median() and mode() methods to calculate the respective values for a specified column:

# %% [raw]
# Mean = the average value (the sum of all values divided by number of values).

# %%
import pandas as pd

df = pd.read_csv('C:/Users/lenovo/Desktop/datasets/Sampledata.csv')

x = df["Calories"].mean()
print(x)
# Out:
# 304.68

# %% [raw]
# Median = the value in the middle, after you have sorted all values ascending.

# %%
import pandas as pd

df = pd.read_csv('C:/Users/lenovo/Desktop/datasets/Sampledata.csv')

x = df["Calories"].median()
print(x)
# Out:
# 291.2

# %% [raw]
# Mode = the value that appears most frequently.

# %%
import pandas as pd

df = pd.read_csv('C:/Users/lenovo/Desktop/datasets/Sampledata.csv')

x = df["Calories"].mode()
print(x)
# Out:
# 0    300.0
# dtype: float64

# %% [markdown]
# # Pandas - Cleaning Data of Wrong Format

# %% [markdown]
# Data of Wrong Format
#
# Cells with data of wrong format can make it difficult, or even impossible, to analyze data.
#
# To fix it, you have two options: remove the rows, or convert all cells in the columns into the same format.
#
# Convert Into a Correct Format
# In our Data Frame, we have two cells with the wrong format. Check out row 22 and 26, the 'Date' column should be a string that represents a date:

# %%
import pandas as pd

df = pd.read_csv('C:/Users/lenovo/Desktop/datasets/Sampledata.csv')


print(df.head(34))
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# Let's try to convert all cells in the 'Date' column into dates.
#
# Pandas has a to_datetime() method for this:

# %%
import pandas as pd

df = pd.read_csv('C:/Users/lenovo/Desktop/datasets/Sampledata.csv')

df['Date'] = pd.to_datetime(df['Date'])
print(df.head(34))
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
import pandas as pd

df = pd.read_csv('C:/Users/lenovo/Desktop/datasets/Sampledata.csv')

df['Date'] = pd.to_datetime(df['Date'])
df.dropna(subset=['Date'], inplace = True)
print(df.head(34))
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %% [markdown]
# # Pandas - Fixing Wrong Data

# %% [markdown]
# # Wrong Data
#
# "Wrong data" does not have to be "empty cells" or "wrong format",
# it can just be wrong, like if someone registered "199" instead of "1.99".

# %% [markdown]
# Replacing Values
# One way to fix wrong values is to replace them with something else.
# In our example,
# it is most likely a typo, and the value should be "45" instead of "450", and we could just insert "45" in row 7:

# %%
df.loc[7, 'Duration'] = 45
print(df.head(34))
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7         45 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
#Loop through all values in the "Duration" column.
#If the value is higher than 120, set it to 120:

for x in df.index:
  if df.loc[x, "Duration"] > 120:
    df.loc[x, "Duration"] = 120

print(df["Duration"])
# Out:
# 0     60
# 1     60
# 2     60
# 3     45
# 4     45
# 5     60
# 6     60
# 7     45
# 8     30
# 9     60
# 10    60
# 11    60
# 12    60
# 13    60
# 14    60
# 15    60
# 16    60
# 17    60
# 18    45
# 19    60
# 20    45
# 21    60
# 22    45
# 23    60
# 24    45
# 25    60
# 26    60
# 27    60
# 28    60
# 29    60
# 30    60
# 31    60
# Name: Duration, dtype: int64

# %%
#Delete rows where "Duration" is higher than 120:

for x in df.index:
  if df.loc[x, "Duration"] > 120:
    df.drop(x, inplace = True)

print(df["Duration"])

# %% [markdown]
# # Pandas - Removing Duplicates

# %% [markdown]
# The duplicated() method returns a Boolean values for each row:

# %%
#Returns True for every row that is a duplicate, othwerwise False:

print(df.duplicated())
print(df)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7         45 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# ...

# %% [markdown]
# # Removing Duplicates
#
# To remove duplicates, use the drop_duplicates() method.

# %%
df.drop_duplicates(inplace = True)
print(df)

# %% [markdown]
# Remember: The (inplace = True) will make sure that the method does
# NOT return a new DataFrame, but it will remove all duplicates from the
# original DataFrame.

# %% [markdown]
# # Pandas - Plotting

# %% [markdown]
# # Plotting
# Pandas uses the plot() method to create diagrams.
#
# Pythons uses Pyplot, a submodule of the Matplotlib library to visualize
# the diagram on the screen.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('C:/Users/lenovo/Desktop/datasets/data.csv')

df.plot()

#plt.show()

# %% [markdown]
# # Scatter Plot
#
# Specify that you want a scatter plot with the kind argument:
#
# kind = 'scatter'
#
# A scatter plot needs an x- and a y-axis.
#
# In the example below we will use "Duration" for the x-axis and "Calories" for the y-axis.
#
# Include the x and y arguments like this:
#
# x = 'Duration', y = 'Calories'

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('C:/Users/lenovo/Desktop/datasets/data.csv')

df.plot(kind = 'scatter', x = 'Duration', y = 'Calories')

#plt.show()

# %% [markdown]
# # Histogram
#
# Use the kind argument to specify that you want a histogram:
#
# kind = 'hist'
#
# A histogram needs only one column.
#
# A histogram shows us the frequency of each interval, e.g. how many workouts lasted between 50 and 60 minutes?
#
# In the example below we will use the "Duration" column to create the histogram:

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('C:/Users/lenovo/Desktop/datasets/data.csv')

df["Duration"].plot(kind = 'hist')

# %%
import pandas as pd

df = pd.read_csv('C:/Users/lenovo/Desktop/datasets/data.csv')
df.shape
# Out:
# (169, 4)

# %%
df.isnull().any()
# Out:
# Duration    False
# Pulse       False
# Maxpulse    False
# Calories     True
# dtype: bool

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
filter_1 = df['Duration']>60
filter_1.any()
# Out:
# True

# %%
filter_1 = df['Duration']>60
filter_1.all()
# Out:
# False

# %%
df.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922717
# Pulse    -0.155408  1.000000  0.786535  0.025121
# Maxpulse  0.009403  0.786535  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000

# %%
df['Duration'].std()
# Out:
# 42.299949341408286

# %% [markdown]
# # slicing  and filter

# %%
df[['Duration','Pulse']].head(10)
# Out:
#    Duration  Pulse
# 0        60    110
# 1        60    117
# 2        60    103
# 3        45    109
# 4        45    117
# 5        60    102
# 6        60    110
# 7        45    104
# 8        30    109
# 9        60     98

# %%
df[5:25]
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 5         60    102       127     300.0
# 6         60    110       136     374.0
# 7         45    104       134     253.3
# 8         30    109       133     195.1
# 9         60     98       124     269.0
# 10        60    103       147     329.3
# 11        60    100       120     250.7
# 12        60    106       128     345.3
# 13        60    104       132     379.3
# 14        60     98       123     275.0
# 15        60     98       120     215.2
# 16        60    100       120     300.0
# 17        45     90       112       NaN
# 18        60    103       123     323.0
# 19        45     97       125     243.0
# 20        60    108       131     364.2
# 21        45    100       119     282.0
# 22        60    130       101     300.0
# 23        45    105       132     246.0
# 24        60    102       126     334.5

# %%
import pandas as pd

mv = pd.read_csv('C:/Users/lenovo/Desktop/datasets/movies.csv')
mv.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
movie_genres=mv['genres'].str.split('|',expand=False)
movie_genres.head(10)
# Out:
# 0    [Adventure, Animation, Children, Comedy, Fantasy]
# 1                       [Adventure, Children, Fantasy]
# 2                                    [Comedy, Romance]
# 3                             [Comedy, Drama, Romance]
# 4                                             [Comedy]
# 5                            [Action, Crime, Thriller]
# 6                                    [Comedy, Romance]
# 7                                [Adventure, Children]
# 8                                             [Action]
# 9                        [Action, Adventure, Thriller]
# Name: genres, dtype: object

# %%
movie_genres=mv['genres'].str.split('|',expand= True)
movie_genres.head(10)
# Out:
#            0          1         2       3        4     5     6     7     8  \
# 0  Adventure  Animation  Children  Comedy  Fantasy  None  None  None  None
# 1  Adventure   Children   Fantasy    None     None  None  None  None  None
# 2     Comedy    Romance      None    None     None  None  None  None  None
# 3     Comedy      Drama   Romance    None     None  None  None  None  None
# 4     Comedy       None      None    None     None  None  None  None  None
# 5     Action      Crime  Thriller    None     None  None  None  None  None
# 6     Comedy    Romance      None    None     None  None  None  None  None
# 7  Adventure   Children      None    None     None  None  None  None  None
# 8     Action       None      None    None     None  None  None  None  None
# 9     Action  Adventure  Thriller    None     None  None  None  None  None
#
#       9
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None
# 5  None
# 6  None
# 7  None
# 8  None
# 9  None

# %%
import pandas as pd
rate = pd.read_csv('C:/Users/lenovo/Desktop/datasets/ratings.csv')
rate.head(10)
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510
# 5       1     1088     4.0  1147868495
# 6       1     1175     3.5  1147868826
# 7       1     1217     3.5  1147878326
# 8       1     1237     5.0  1147868839
# 9       1     1250     4.0  1147868414

# %% [markdown]
# # Groupby

# %% [markdown]
# https://pandas.pydata.org/docs/user_guide/groupby.html#groupby

# %%
rate_count=rate[['movieId','rating']].groupby('rating').count()
rate_count
# Out:
#         movieId
# rating
# 0.5      393068
# 1.0      776815
# 1.5      399490
# 2.0     1640868
# 2.5     1262797
# 3.0     4896928
# 3.5     3177318
# 4.0     6639798
# 4.5     2200539
# 5.0     3612474

# %%
movie_count=rate[['movieId','rating']].groupby('movieId').count()
movie_count.head(10)
# Out:
#          rating
# movieId
# 1         57309
# 2         24228
# 3         11804
# 4          2523
# 5         11714
# 6         24588
# 7         12132
# 8          1344
# 9          3711
# 10        28265

# %%
movie_count.tail(10)
# Out:
#          rating
# movieId
# 209145        1
# 209147        2
# 209151        1
# 209153        1
# 209155        1
# 209157        1
# 209159        1
# 209163        1
# 209169        1
# 209171        1

# %%
movie_count_mean=rate[['movieId','rating']].groupby('movieId').mean()
movie_count_mean.head()
# Out:
#            rating
# movieId
# 1        3.893708
# 2        3.251527
# 3        3.142028
# 4        2.853547
# 5        3.058434

# %% [markdown]
# # Merge

# %% [markdown]
# https://pandas.pydata.org/docs/user_guide/merging.html#merging

# %%
mv.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
merge_mv_rate=mv.merge(rate,on='movieId', how='inner') #intersection, not null
merge_mv_rate[:10]
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 5        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 6        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 7        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 8        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 9        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating   timestamp
# 0       2     3.5  1141415820
# 1       3     4.0  1439472215
# 2       4     3.0  1573944252
# ...

# %%
merge_mv_rate=mv.merge(rate,on='movieId', how='outer')# union , null value
merge_mv_rate[:10]
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 5        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 6        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 7        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 8        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 9        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating     timestamp
# 0     2.0     3.5  1.141416e+09
# 1     3.0     4.0  1.439472e+09
# 2     4.0     3.0  1.573944e+09
# ...

# %% [markdown]
# # How many Adventure movies are there which having rating above 4.0?

# %%
mv.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
#del rate['userId']
#del rate['timestamp']
rate.head()
# Out:
#    movieId  rating
# 0      296     5.0
# 1      306     3.5
# 2      307     5.0
# 3      665     5.0
# 4      899     3.5

# %%
adv_movie=mv.merge(rate, on='movieId',how='inner')
adv_movie[:10]
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 5        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 6        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 7        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 8        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 9        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    rating
# 0     3.5
# 1     4.0
# 2     3.0
# 3     4.0
# 4     4.0
# 5     3.5
# 6     4.0
# 7     4.0
# 8     3.0
# 9     3.0

# %%
is_high_rate=adv_movie['rating']>=4.0
adv_movie[is_high_rate][:5]
# Out:
#    movieId             title                                       genres  \
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 6        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 7        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    rating
# 1     4.0
# 3     4.0
# 4     4.0
# 6     4.0
# 7     4.0

# %%
is_adventure=adv_movie['genres'].str.contains('Adventure')
#del adv_movie['userId']
#del adv_movie['timestamp']
adv_movie[is_adventure][:5]
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    rating
# 0     3.5
# 1     4.0
# 2     3.0
# 3     4.0
# 4     4.0

# %%
final_count=adv_movie[is_adventure & is_high_rate ][:-10]
final_count.tail(10)
# Out:
#           movieId                            title  \
# 24998973   206899          Charlie's Angels (2019)
# 24998995   206919     Garfield: His 9 Lives (1988)
# 24999030   206959                 Frozen II (2019)
# 24999150   207149       The Ultimate Legacy (2015)
# 24999329   207347         Spread Your Wings (2019)
# 24999451   207530         Boys Will Be Boys (1976)
# 24999457   207556        Krakonoš a lyžníci (1981)
# 24999811   208253      A Wind Named Amnesia (1990)
# 24999814   208265  Rolli and the Golden Key (2013)
# 24999815   208267          Ella and Friends (2012)
#
#                                                genres  rating
# 24998973                      Action|Adventure|Comedy     5.0
# 24998995                   Adventure|Animation|Comedy     4.5
# 24999030  Adventure|Animation|Children|Comedy|Fantasy     4.5
# 24999150                       Adventure|Comedy|Drama     5.0
# 24999329                           Adventure|Children     4.5
# ...

# %%
#print(final_count)
final_count.shape
# Out:
# (2843623, 4)

# %% [markdown]
# 2843623 are adventure movies having rating greator than 4.0

# %% [markdown]
#  adventure movies having greater than 4.0 counting by rating and bar digram

# %%
rating_count=final_count['rating'].value_counts()
rating_count
# Out:
# 4.0    1491721
# 5.0     838497
# 4.5     513405
# Name: rating, dtype: int64

# %%
# %matplotlib inline
rating_count.plot(kind = 'bar', figsize=(5,5))
